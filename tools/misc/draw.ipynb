# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
marker = 'o--'
label = 'R-50/ 101'
x = [43.5, 51.3]
y = [44.3, 48.5]
plt.plot(x, y, marker, label=label)

marker = 's--'
label = 'Swin-T/ S/ B'
x = [43.9, 59.9, 78.1]
y = [47.1, 52.6, 53.2]
plt.plot(x, y, marker, label=label)

marker = '^--'
label = 'TDViT-T / T$^+$/ S / S$^+$/ B / B$^+$/'
x = [41.8, 50.8, 57.8, 65.4, 77.5, 84.7]
y = [47.8, 50.9, 55.4, 55.7, 56.0, 56.1]
plt.plot(x, y, marker, label=label)


# marker = 'd--'
# label = r'TDViT-T$^+$/ S$^+$/ B$^+$'
# x = [51.5]
# y = [79.9]
# plt.plot(x, y, marker, label=label)


plt.xlabel('runtime (ms)')
plt.ylabel(r'accuracy (AP$_{50}$)')

# plt.xlim(35, 85)
# plt.ylim(72, 88)
plt.legend(shadow=True)
# plt.legend().get_frame().set_facecolor('C0')
#plt.savefig('foo.png')
#plt.savefig('foo.pdf')
